# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("thesis master chart.xlsx")

# %%
df = df.dropna()

# %%
df.head()
# Out:
#         NAME  AGE\n(YRS) SEX  MANUBRIUM LENGTH\n(ML) (CM)  \
# 0   SAMPLE 1          20   M                         3.35
# 1  SAMPLE  2          20   F                         3.58
# 2   SAMPLE 3          20   F                         4.67
# 3   SAMPLE 4          20   M                         3.90
# 4   SAMPLE 5          20   M                         4.95
#
#    MESOSTERNM \nLENGTH\n(BL) (CM)  MANUBRIUM \nWIDTH\n(MW)  SW1\n(CM)  \
# 0                            7.93                     4.21       2.21
# 1                            9.00                     4.62       1.85
# 2                            8.95                     4.84       1.80
# 3                            9.00                     5.78       2.34
# 4                            7.96                     5.60       2.44
#
#    SW2\n(CM) TSL \n(MM)  TSL\n(ML+BL)\n(CM)  STERNAL INDEX \n(M/B X100)(CM)  \
# 0       1.67      112.8               11.28                           42.24
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   AGE
# (YRS)                                   150 non-null    int64
#  1   SEX                                         150 non-null    int64
#  2   MANUBRIUM LENGTH
# (ML) (CM)                  150 non-null    float64
#  3   MESOSTERNM
# LENGTH
# (BL) (CM)                150 non-null    float64
#  4   MANUBRIUM
# WIDTH
# (MW)                       150 non-null    float64
#  5   SW1
# (CM)                                    150 non-null    float64
#  6   SW2
# (CM)                                    150 non-null    float64
#  7   TSL
# (MM)                                   150 non-null    float64
#  8   TSL
# (ML+BL)
# (CM)                            150 non-null    float64
#  9   STERNAL INDEX
# ...

# %%
df.describe()
# Out:
#        AGE\n(YRS)         SEX  MANUBRIUM LENGTH\n(ML) (CM)  \
# count  150.000000  150.000000                   150.000000
# mean    49.313333    0.613333                     3.995133
# std     15.860608    0.488618                     0.619071
# min     20.000000    0.000000                     2.440000
# 25%     38.000000    0.000000                     3.580000
# 50%     50.000000    1.000000                     4.010000
# 75%     62.000000    1.000000                     4.442500
# max     80.000000    1.000000                     5.370000
#
#        MESOSTERNM \nLENGTH\n(BL) (CM)  MANUBRIUM \nWIDTH\n(MW)   SW1\n(CM)  \
# count                      150.000000               150.000000  150.000000
# mean                         8.893467                 5.566333    2.543467
# std                          1.411231                 0.922155    0.386302
# min                          4.210000                 3.850000    1.800000
# ...

# %%
df["SEX"].unique()
# Out:
# array(['M', 'F', 'm', 'f', 'f ', 'M '], dtype=object)

# %%
df['SEX'] = df['SEX'].str.strip().str.upper()

# %%
df["SEX"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["SEX"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df["SEX"] = df['SEX'].map({'M': 1, 'F': 0}).astype('int64')

# %%
df
# Out:
#            NAME  AGE\n(YRS)  SEX  MANUBRIUM LENGTH\n(ML) (CM)  \
# 0      SAMPLE 1          20    1                         3.35
# 1     SAMPLE  2          20    0                         3.58
# 2      SAMPLE 3          20    0                         4.67
# 3      SAMPLE 4          20    1                         3.90
# 4      SAMPLE 5          20    1                         4.95
# ..          ...         ...  ...                          ...
# 145  SAMPLE 146          76    1                         4.15
# 146  SAMPLE 147          76    0                         3.34
# 147  SAMPLE 148          79    1                         4.06
# 148  SAMPLE 149          80    1                         5.16
# 149  SAMPLE 150          80    0                         3.78
#
#      MESOSTERNM \nLENGTH\n(BL) (CM)  MANUBRIUM \nWIDTH\n(MW)  SW1\n(CM)  \
# 0                              7.93                     4.21       2.21
# 1                              9.00                     4.62       1.85
# ...

# %%
sns.histplot(df["TSL\n(ML+BL)\n(CM)"],kde = True)
# Out:
# <Axes: xlabel='TSL\n(ML+BL)\n(CM)', ylabel='Count'>

# %%
sns.boxplot(y = df["AGE\n(YRS)"])
# Out:
# <Axes: ylabel='AGE\n(YRS)'>

# %%
sns.violinplot(y = df["AGE\n(YRS)"])
# Out:
# <Axes: ylabel='AGE\n(YRS)'>

# %%
sns.kdeplot(df["AGE\n(YRS)"], fill = True)
# Out:
# <Axes: xlabel='AGE\n(YRS)', ylabel='Density'>

# %%
df = df.drop(["NAME"], axis = 1)

# %%
df
# Out:
#      AGE\n(YRS)  SEX  MANUBRIUM LENGTH\n(ML) (CM)  \
# 0            20    1                         3.35
# 1            20    0                         3.58
# 2            20    0                         4.67
# 3            20    1                         3.90
# 4            20    1                         4.95
# ..          ...  ...                          ...
# 145          76    1                         4.15
# 146          76    0                         3.34
# 147          79    1                         4.06
# 148          80    1                         5.16
# 149          80    0                         3.78
#
#      MESOSTERNM \nLENGTH\n(BL) (CM)  MANUBRIUM \nWIDTH\n(MW)  SW1\n(CM)  \
# 0                              7.93                     4.21       2.21
# 1                              9.00                     4.62       1.85
# 2                              8.95                     4.84       1.80
# ...

# %%
X = df.drop(columns = ["SEX"])
y = df["SEX"]

# %%
X.shape
# Out:
# (150, 10)

# %%
y.shape
# Out:
# (150,)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histograms to check distribution of each column

df.hist(figsize=(12, 15), bins=20)
plt.show()

# %%
# before applying standard scaler we want to clean the data,, as in one column a data point contain "91.3 cm" so we have to do it as "91.3"

# Check which columns contain the string "cm"
columns_with_cm = df.apply(lambda col: col.astype(str).str.contains("cm", case=False, na=False)).any()

# Print the column names that contain "cm"
print("Columns containing 'cm':")
print(columns_with_cm[columns_with_cm].index.tolist())
# Out:
# Columns containing 'cm':
# ['TSL \n(MM)']

# %%
print(df['TSL \n(MM)'].to_string())
# Out:
# 0        112.8
# 1        125.8
# 2        136.2
# 3          129
# 4        129.1
# 5        132.7
# 6        107.4
# 7        134.8
# 8        120.8
# 9        117.2
# 10       137.7
# 11       132.6
# 12       132.4
# 13       130.3
# 14       128.6
# 15       161.5
# 16       147.8
# 17       120.2
# 18       137.4
# 19       143.3
# 20         131
# 21       144.2
# 22       146.2
# 23       130.4
# 24       127.5
# 25       110.4
# 26       132.2
# 27         151
# 28       147.2
# 29       115.5
# 30       113.3
# 31       130.4
# 32         147
# 33         119
# 34       135.1
# 35       113.7
# 36       110.8
# 37       120.8
# 38       112.8
# 39       120.2
# 40       105.2
# 41       144.3
# 42       112.7
# 43       135.1
# 44       105.5
# 45       143.4
# 46         114
# 47       137.2
# 48       130.2
# 49       138.6
# 50       113.8
# 51       131.1
# 52       131.6
# 53       100.4
# 54       128.1
# 55         119
# 56       119.3
# 57       107.9
# ...

# %%
df.at[116, 'TSL \n(MM)'] = float(str(df.at[116, 'TSL \n(MM)']).replace("cm", ""))

# %%
print(df.loc[116, 'TSL \n(MM)'])
# Out:
# 91.3

# %%
df['TSL \n(MM)'] = df['TSL \n(MM)'].astype(str).str.replace("cm", "", regex=False).astype(float)

# %%
X.loc[:, 'TSL \n(MM)'] = df['TSL \n(MM)']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_std_scaled = scaler.fit_transform(X)

# %%
X_std_scaled
# Out:
# array([[-1.85437633, -1.04558967, -0.68500077, ..., -0.97391091,
#         -0.36911635, -1.6549919 ],
#        [-1.85437633, -0.6728208 ,  0.07574254, ..., -0.17579102,
#         -0.62240476, -0.92440191],
#        [-1.85437633,  1.09377951,  0.04019379, ...,  0.46270489,
#          0.61412137, -0.37408738],
#        ...,
#        [ 1.87799358,  0.10513163,  1.46214391, ...,  1.31607923,
#         -0.88466797,  1.35181287],
#        [ 1.94125409,  1.88793928,  0.62319334, ...,  1.26696416,
#          0.68492246,  0.69807715],
#        [ 1.94125409, -0.34867396, -0.33662299, ..., -0.40908761,
#         -0.10485875, -0.69668555]])

# %%
# using StandardScaler normalized data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_std_scaled,y,test_size = 0.2)

# %%
y
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 145    1
# 146    0
# 147    1
# 148    1
# 149    0
# Name: SEX, Length: 150, dtype: int64

# %% [markdown]
# ## Now applying the CNN

# %%
print(X_std_scaled.shape)
# Out:
# (150, 10)

# %%
X_std_scaled = X_std_scaled.reshape((150,10,1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(
    monitor='val_loss',    # you can also use 'val_accuracy'
    patience=5,            # stop after 5 epochs with no improvement
    restore_best_weights=True
)

# %%
model  = Sequential()

model.add(Conv1D(32,kernel_size=2, activation="relu", input_shape = (10,1)))
model.add(MaxPooling1D(pool_size = 2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /Users/nileshsingh/anaconda3/envs/tf_env/lib/python3.9/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=30, batch_size=16, validation_data=(X_test, y_test),callbacks=[early_stop])
# Out:
# Epoch 1/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6282 - loss: 0.6751 - val_accuracy: 0.6667 - val_loss: 0.5936
# Epoch 2/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8483 - loss: 0.5327 - val_accuracy: 0.8000 - val_loss: 0.5239
# Epoch 3/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8822 - loss: 0.4467 - val_accuracy: 0.8000 - val_loss: 0.4866
# Epoch 4/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8625 - loss: 0.4033 - val_accuracy: 0.8333 - val_loss: 0.4668
# Epoch 5/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8344 - loss: 0.3994 - val_accuracy: 0.8333 - val_loss: 0.4672
# Epoch 6/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9107 - loss: 0.2896 - val_accuracy: 0.8333 - val_loss: 0.4678
# Epoch 7/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8680 - loss: 0.3382 - val_accuracy: 0.8333 - val_loss: 0.4724
# Epoch 8/30
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 0.4668
# Test Loss: 0.4668
# Test Accuracy: 0.8333

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title("Model Accuracy")
plt.show()

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Model Loss")
plt.show()
