# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("thesis master chart.xlsx")

# %%
df = df.dropna()

# %%
df.head()
# Out:
#         NAME  AGE\n(YRS) SEX  MANUBRIUM LENGTH\n(ML) (CM)  \
# 0   SAMPLE 1          20   M                         3.35
# 1  SAMPLE  2          20   F                         3.58
# 2   SAMPLE 3          20   F                         4.67
# 3   SAMPLE 4          20   M                         3.90
# 4   SAMPLE 5          20   M                         4.95
#
#    MESOSTERNM \nLENGTH\n(BL) (CM)  MANUBRIUM \nWIDTH\n(MW)  SW1\n(CM)  \
# 0                            7.93                     4.21       2.21
# 1                            9.00                     4.62       1.85
# 2                            8.95                     4.84       1.80
# 3                            9.00                     5.78       2.34
# 4                            7.96                     5.60       2.44
#
#    SW2\n(CM) TSL \n(MM)  TSL\n(ML+BL)\n(CM)  STERNAL INDEX \n(M/B X100)(CM)  \
# 0       1.67      112.8               11.28                           42.24
# 1       2.64      125.8               12.58                           39.70
# 2       3.05      136.2               13.62                           52.10
# 3       3.60        129               12.90                           43.30
# 4       3.39      129.1               12.91                           62.10
#
#    STERNAL AREA \n{(M+B)X (MW+S1W+S2W)/3} (CM)
# 0                                         30.4
# 1                                         38.1
# 2                                         43.9
# 3                                         50.3
# 4                                         49.1

# %%
df["SEX"].unique()
# Out:
# array(['M', 'F', 'm', 'f', 'f ', 'M '], dtype=object)

# %%
df['SEX'] = df['SEX'].str.strip().str.upper()

# %%
df["SEX"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["SEX"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df["SEX"] = df['SEX'].map({'M': 1, 'F': 0}).astype('int64')

# %%
df
# Out:
#            NAME  AGE\n(YRS)  SEX  MANUBRIUM LENGTH\n(ML) (CM)  \
# 0      SAMPLE 1          20    1                         3.35
# 1     SAMPLE  2          20    0                         3.58
# 2      SAMPLE 3          20    0                         4.67
# 3      SAMPLE 4          20    1                         3.90
# 4      SAMPLE 5          20    1                         4.95
# ..          ...         ...  ...                          ...
# 145  SAMPLE 146          76    1                         4.15
# 146  SAMPLE 147          76    0                         3.34
# 147  SAMPLE 148          79    1                         4.06
# 148  SAMPLE 149          80    1                         5.16
# 149  SAMPLE 150          80    0                         3.78
#
#      MESOSTERNM \nLENGTH\n(BL) (CM)  MANUBRIUM \nWIDTH\n(MW)  SW1\n(CM)  \
# 0                              7.93                     4.21       2.21
# 1                              9.00                     4.62       1.85
# 2                              8.95                     4.84       1.80
# 3                              9.00                     5.78       2.34
# 4                              7.96                     5.60       2.44
# ..                              ...                      ...        ...
# 145                           10.51                     5.96       2.77
# 146                            7.93                     5.06       1.85
# 147                           10.95                     5.89       2.75
# 148                            9.77                     5.53       2.79
# 149                            8.42                     5.45       2.19
#
#      SW2\n(CM) TSL \n(MM)  TSL\n(ML+BL)\n(CM)  STERNAL INDEX \n(M/B X100)(CM)  \
# 0         1.67      112.8               11.28                           42.24
# 1         2.64      125.8               12.58                           39.70
# 2         3.05      136.2               13.62                           52.10
# 3         3.60        129               12.90                           43.30
# 4         3.39      129.1               12.91                           62.10
# ..         ...        ...                 ...                             ...
# 145       3.14      146.6               14.66                           39.48
# 146       2.37      112.7               11.27                           42.11
# 147       3.77      150.1               15.01                           37.07
# 148       2.79      149.3               14.93                           52.81
# 149       2.32        122               12.20                           44.89
#
#      STERNAL AREA \n{(M+B)X (MW+S1W+S2W)/3} (CM)
# 0                                          30.40
# 1                                          38.10
# 2                                          43.90
# 3                                          50.30
# 4                                          49.10
# ..                                           ...
# 145                                        58.00
# 146                                        34.86
# 147                                        62.09
# 148                                        55.20
# 149                                        40.50
#
# [150 rows x 12 columns]

# %%
sns.histplot(df["TSL\n(ML+BL)\n(CM)"],kde = True)
# Out:
# <Axes: xlabel='TSL\n(ML+BL)\n(CM)', ylabel='Count'>

# %%
sns.boxplot(y = df["AGE\n(YRS)"])
# Out:
# <Axes: ylabel='AGE\n(YRS)'>

# %%
sns.violinplot(y = df["AGE\n(YRS)"])
# Out:
# <Axes: ylabel='AGE\n(YRS)'>

# %%
sns.kdeplot(df["AGE\n(YRS)"], fill = True)
# Out:
# <Axes: xlabel='AGE\n(YRS)', ylabel='Density'>

# %%
df = df.drop(["NAME"], axis = 1)

# %%
df
# Out:
#      AGE\n(YRS)  SEX  MANUBRIUM LENGTH\n(ML) (CM)  \
# 0            20    1                         3.35
# 1            20    0                         3.58
# 2            20    0                         4.67
# 3            20    1                         3.90
# 4            20    1                         4.95
# ..          ...  ...                          ...
# 145          76    1                         4.15
# 146          76    0                         3.34
# 147          79    1                         4.06
# 148          80    1                         5.16
# 149          80    0                         3.78
#
#      MESOSTERNM \nLENGTH\n(BL) (CM)  MANUBRIUM \nWIDTH\n(MW)  SW1\n(CM)  \
# 0                              7.93                     4.21       2.21
# 1                              9.00                     4.62       1.85
# 2                              8.95                     4.84       1.80
# 3                              9.00                     5.78       2.34
# 4                              7.96                     5.60       2.44
# ..                              ...                      ...        ...
# 145                           10.51                     5.96       2.77
# 146                            7.93                     5.06       1.85
# 147                           10.95                     5.89       2.75
# 148                            9.77                     5.53       2.79
# 149                            8.42                     5.45       2.19
#
#      SW2\n(CM) TSL \n(MM)  TSL\n(ML+BL)\n(CM)  STERNAL INDEX \n(M/B X100)(CM)  \
# 0         1.67      112.8               11.28                           42.24
# 1         2.64      125.8               12.58                           39.70
# 2         3.05      136.2               13.62                           52.10
# 3         3.60        129               12.90                           43.30
# 4         3.39      129.1               12.91                           62.10
# ..         ...        ...                 ...                             ...
# 145       3.14      146.6               14.66                           39.48
# 146       2.37      112.7               11.27                           42.11
# 147       3.77      150.1               15.01                           37.07
# 148       2.79      149.3               14.93                           52.81
# 149       2.32        122               12.20                           44.89
#
#      STERNAL AREA \n{(M+B)X (MW+S1W+S2W)/3} (CM)
# 0                                          30.40
# 1                                          38.10
# 2                                          43.90
# 3                                          50.30
# 4                                          49.10
# ..                                           ...
# 145                                        58.00
# 146                                        34.86
# 147                                        62.09
# 148                                        55.20
# 149                                        40.50
#
# [150 rows x 11 columns]

# %%
X = df.drop(columns = ["SEX"])
y = df["SEX"]

# %%
X.shape
# Out:
# (150, 10)

# %%
y.shape
# Out:
# (150,)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histograms to check distribution of each column

df.hist(figsize=(12, 15), bins=20)
plt.show()

# %%
# before applying standard scaler we want to clean the data,, as in one column a data point contain "91.3 cm" so we have to do it as "91.3"

# Check which columns contain the string "cm"
columns_with_cm = df.apply(lambda col: col.astype(str).str.contains("cm", case=False, na=False)).any()

# Print the column names that contain "cm"
print("Columns containing 'cm':")
print(columns_with_cm[columns_with_cm].index.tolist())
# Out:
# Columns containing 'cm':
# ['TSL \n(MM)']

# %%
print(df['TSL \n(MM)'].to_string())
# Out:
# 0        112.8
# 1        125.8
# 2        136.2
# 3          129
# 4        129.1
# 5        132.7
# 6        107.4
# 7        134.8
# 8        120.8
# 9        117.2
# 10       137.7
# 11       132.6
# 12       132.4
# 13       130.3
# 14       128.6
# 15       161.5
# 16       147.8
# 17       120.2
# 18       137.4
# 19       143.3
# 20         131
# 21       144.2
# 22       146.2
# 23       130.4
# 24       127.5
# 25       110.4
# 26       132.2
# 27         151
# 28       147.2
# 29       115.5
# 30       113.3
# 31       130.4
# 32         147
# 33         119
# 34       135.1
# 35       113.7
# 36       110.8
# 37       120.8
# 38       112.8
# 39       120.2
# 40       105.2
# 41       144.3
# 42       112.7
# 43       135.1
# 44       105.5
# 45       143.4
# 46         114
# 47       137.2
# 48       130.2
# 49       138.6
# 50       113.8
# 51       131.1
# 52       131.6
# 53       100.4
# 54       128.1
# 55         119
# 56       119.3
# 57       107.9
# 58       136.2
# 59        85.9
# 60        98.9
# 61         139
# 62       134.9
# 63         124
# 64       116.9
# 65         165
# 66       118.8
# 67       116.4
# 68         108
# 69       126.8
# 70       116.4
# 71       145.1
# 72       132.6
# 73       131.1
# 74         151
# 75       106.1
# 76       143.3
# 77       111.6
# 78       103.1
# 79       143.9
# 80       145.2
# 81       150.9
# 82       134.1
# 83       138.3
# 84       149.4
# 85       144.5
# 86       118.7
# 87       112.6
# 88       132.8
# 89         119
# 90       158.3
# 91       112.9
# 92       117.5
# 93       108.2
# 94         151
# 95       109.8
# 96       149.2
# 97       145.1
# 98          93
# 99       132.2
# 100      108.2
# 101      142.9
# 102       93.6
# 103      118.9
# 104        144
# 105      135.9
# 106      131.5
# 107      130.1
# 108      128.9
# 109      123.7
# 110      124.8
# 111      150.1
# 112      138.3
# 113      150.2
# 114      116.2
# 115      132.1
# 116    91.3 cm
# 117      144.6
# 118      137.7
# 119      117.6
# 120      152.8
# 121      157.6
# 122      148.5
# 123      115.1
# 124      102.7
# 125      108.2
# 126      151.2
# 127      143.6
# 128        118
# 129      104.8
# 130      130.8
# 131      107.1
# 132      108.2
# 133      131.3
# 134      106.4
# 135      118.7
# 136      134.8
# 137        146
# 138      138.7
# 139      135.7
# 140      139.2
# 141      150.2
# 142      154.8
# 143        135
# 144      147.5
# 145      146.6
# 146      112.7
# 147      150.1
# 148      149.3
# 149        122

# %%
df.at[116, 'TSL \n(MM)'] = float(str(df.at[116, 'TSL \n(MM)']).replace("cm", ""))

# %%
print(df.loc[116, 'TSL \n(MM)'])
# Out:
# 91.3

# %%
df['TSL \n(MM)'] = df['TSL \n(MM)'].astype(str).str.replace("cm", "", regex=False).astype(float)

# %%
X.loc[:, 'TSL \n(MM)'] = df['TSL \n(MM)']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_minMax_scaled = scaler.fit_transform(X)

# %%
X_minMax_scaled
# Out:
# array([[0.        , 0.3105802 , 0.46268657, ..., 0.34007585, 0.26061984,
#         0.17910448],
#        [0.        , 0.3890785 , 0.59577114, ..., 0.50442478, 0.23022616,
#         0.32276119],
#        [0.        , 0.76109215, 0.58955224, ..., 0.63590392, 0.37860476,
#         0.43097015],
#        ...,
#        [0.98333333, 0.55290102, 0.83830846, ..., 0.81163085, 0.19875553,
#         0.77033582],
#        [1.        , 0.92832765, 0.69154229, ..., 0.80151707, 0.38710063,
#         0.64179104],
#        [1.        , 0.45733788, 0.52363184, ..., 0.45638432, 0.29232978,
#         0.36753731]])

# %%
# using StandardScaler normalized data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_minMax_scaled,y,test_size = 0.2)

# %%
y
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 145    1
# 146    0
# 147    1
# 148    1
# 149    0
# Name: SEX, Length: 150, dtype: int64

# %% [markdown]
# ## Now applying the CNN

# %%
print(X_minMax_scaled.shape)
# Out:
# (150, 10)

# %%
X_minMax_scaled = X_minMax_scaled.reshape((150,10,1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(
    monitor='val_loss',    # you can also use 'val_accuracy'
    patience=5,            # stop after 5 epochs with no improvement
    restore_best_weights=True
)

# %%
model  = Sequential()

model.add(Conv1D(32,kernel_size=2, activation="relu", input_shape = (10,1)))
model.add(MaxPooling1D(pool_size = 2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /Users/nileshsingh/anaconda3/envs/tf_env/lib/python3.9/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=30, batch_size=16, validation_data=(X_test, y_test),callbacks=[early_stop])
# Out:
# Epoch 1/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6473 - loss: 0.6658 - val_accuracy: 0.6333 - val_loss: 0.6325
# Epoch 2/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6028 - loss: 0.6395 - val_accuracy: 0.6333 - val_loss: 0.6126
# Epoch 3/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.