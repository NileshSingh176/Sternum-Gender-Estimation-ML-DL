# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("thesis master chart.xlsx")

# %%
df.head()
# Out:
#         NAME  AGE\n(YRS) SEX  MANUBRIUM LENGTH\n(ML) (CM)  \
# 0   SAMPLE 1          20   M                         3.35
# 1  SAMPLE  2          20   F                         3.58
# 2   SAMPLE 3          20   F                         4.67
# 3   SAMPLE 4          20   M                         3.90
# 4   SAMPLE 5          20   M                         4.95
#
#    MESOSTERNM \nLENGTH\n(BL) (CM)  MANUBRIUM \nWIDTH\n(MW)  SW1\n(CM)  \
# 0                            7.93                     4.21       2.21
# 1                            9.00                     4.62       1.85
# 2                            8.95                     4.84       1.80
# 3                            9.00                     5.78       2.34
# 4                            7.96                     5.60       2.44
#
#    SW2\n(CM) TSL \n(MM)  TSL\n(ML+BL)\n(CM)  STERNAL INDEX \n(M/B X100)(CM)  \
# 0       1.67      112.8               11.28                           42.24
# ...

# %%
plt.figure(figsize = (15,10))
sns.histplot(df)
plt.show()

# %%
df.describe()
# Out:
#        AGE\n(YRS)  MANUBRIUM LENGTH\n(ML) (CM)  \
# count  150.000000                   150.000000
# mean    49.313333                     3.995133
# std     15.860608                     0.619071
# min     20.000000                     2.440000
# 25%     38.000000                     3.580000
# 50%     50.000000                     4.010000
# 75%     62.000000                     4.442500
# max     80.000000                     5.370000
#
#        MESOSTERNM \nLENGTH\n(BL) (CM)  MANUBRIUM \nWIDTH\n(MW)   SW1\n(CM)  \
# count                      150.000000               150.000000  150.000000
# mean                         8.893467                 5.566333    2.543467
# std                          1.411231                 0.922155    0.386302
# min                          4.210000                 3.850000    1.800000
# 25%                          7.935000                 5.002500    2.305000
# 50%                          8.920000                 5.425000    2.525000
# ...

# %%
sns.pairplot(df,hue = "SEX")
plt.show()

# %%
df
# Out:
#            NAME  AGE\n(YRS) SEX  MANUBRIUM LENGTH\n(ML) (CM)  \
# 0      SAMPLE 1          20   M                         3.35
# 1     SAMPLE  2          20   F                         3.58
# 2      SAMPLE 3          20   F                         4.67
# 3      SAMPLE 4          20   M                         3.90
# 4      SAMPLE 5          20   M                         4.95
# ..          ...         ...  ..                          ...
# 145  SAMPLE 146          76   M                         4.15
# 146  SAMPLE 147          76   F                         3.34
# 147  SAMPLE 148          79   M                         4.06
# 148  SAMPLE 149          80   M                         5.16
# 149  SAMPLE 150          80   F                         3.78
#
#      MESOSTERNM \nLENGTH\n(BL) (CM)  MANUBRIUM \nWIDTH\n(MW)  SW1\n(CM)  \
# 0                              7.93                     4.21       2.21
# 1                              9.00                     4.62       1.85
# ...

# %%
df_nm_drop = df.drop(columns = ["NAME"])

# %%
df_nm_drop
# Out:
#      AGE\n(YRS) SEX  MANUBRIUM LENGTH\n(ML) (CM)  \
# 0            20   M                         3.35
# 1            20   F                         3.58
# 2            20   F                         4.67
# 3            20   M                         3.90
# 4            20   M                         4.95
# ..          ...  ..                          ...
# 145          76   M                         4.15
# 146          76   F                         3.34
# 147          79   M                         4.06
# 148          80   M                         5.16
# 149          80   F                         3.78
#
#      MESOSTERNM \nLENGTH\n(BL) (CM)  MANUBRIUM \nWIDTH\n(MW)  SW1\n(CM)  \
# 0                              7.93                     4.21       2.21
# 1                              9.00                     4.62       1.85
# 2                              8.95                     4.84       1.80
# 3                              9.00                     5.78       2.34
# ...

# %%
df_nm_drop["SEX"].unique()
# Out:
# array(['M', 'F', 'm', 'f', 'f ', 'M '], dtype=object)

# %%
df_nm_drop["SEX"] = df_nm_drop["SEX"].str.strip().str.upper().map({"M":1,"F":0})

# %%
df_nm_drop
# Out:
#      AGE\n(YRS)  SEX  MANUBRIUM LENGTH\n(ML) (CM)  \
# 0            20    1                         3.35
# 1            20    0                         3.58
# 2            20    0                         4.67
# 3            20    1                         3.90
# 4            20    1                         4.95
# ..          ...  ...                          ...
# 145          76    1                         4.15
# 146          76    0                         3.34
# 147          79    1                         4.06
# 148          80    1                         5.16
# 149          80    0                         3.78
#
#      MESOSTERNM \nLENGTH\n(BL) (CM)  MANUBRIUM \nWIDTH\n(MW)  SW1\n(CM)  \
# 0                              7.93                     4.21       2.21
# 1                              9.00                     4.62       1.85
# 2                              8.95                     4.84       1.80
# ...

# %%
X = df_nm_drop.drop(columns = ["SEX"])
y = df_nm_drop["SEX"]

# %%
X.shape
# Out:
# (150, 10)

# %%
y.shape
# Out:
# (150,)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histograms to check distribution
df_nm_drop.hist(figsize=(12, 15), bins=20)
plt.show()

# %%
plt.savefig("normal.png",dpi = 500)

# %%
# Check which columns contain the string "cm"
columns_with_cm = df_nm_drop.apply(lambda col: col.astype(str).str.contains("cm", case=False, na=False)).any()

# Print the column names that contain "cm"
print("Columns containing 'cm':")
print(columns_with_cm[columns_with_cm].index.tolist())
# Out:
# Columns containing 'cm':
# ['TSL \n(MM)']

# %%
print(df_nm_drop['TSL \n(MM)'].to_string())
# Out:
# 0        112.8
# 1        125.8
# 2        136.2
# 3          129
# 4        129.1
# 5        132.7
# 6        107.4
# 7        134.8
# 8        120.8
# 9        117.2
# 10       137.7
# 11       132.6
# 12       132.4
# 13       130.3
# 14       128.6
# 15       161.5
# 16       147.8
# 17       120.2
# 18       137.4
# 19       143.3
# 20         131
# 21       144.2
# 22       146.2
# 23       130.4
# 24       127.5
# 25       110.4
# 26       132.2
# 27         151
# 28       147.2
# 29       115.5
# 30       113.3
# 31       130.4
# 32         147
# 33         119
# 34       135.1
# 35       113.7
# 36       110.8
# 37       120.8
# 38       112.8
# 39       120.2
# 40       105.2
# 41       144.3
# 42       112.7
# 43       135.1
# 44       105.5
# 45       143.4
# 46         114
# 47       137.2
# 48       130.2
# 49       138.6
# 50       113.8
# 51       131.1
# 52       131.6
# 53       100.4
# 54       128.1
# 55         119
# 56       119.3
# 57       107.9
# ...

# %%
df_nm_drop.at[116, 'TSL \n(MM)'] = float(str(df_nm_drop.at[116, 'TSL \n(MM)']).replace("cm", ""))

# %%
print(df_nm_drop.loc[116, 'TSL \n(MM)'])
# Out:
# 91.3

# %%
print(df_nm_drop['TSL \n(MM)'].to_string())
# Out:
# 0      112.8
# 1      125.8
# 2      136.2
# 3        129
# 4      129.1
# 5      132.7
# 6      107.4
# 7      134.8
# 8      120.8
# 9      117.2
# 10     137.7
# 11     132.6
# 12     132.4
# 13     130.3
# 14     128.6
# 15     161.5
# 16     147.8
# 17     120.2
# 18     137.4
# 19     143.3
# 20       131
# 21     144.2
# 22     146.2
# 23     130.4
# 24     127.5
# 25     110.4
# 26     132.2
# 27       151
# 28     147.2
# 29     115.5
# 30     113.3
# 31     130.4
# 32       147
# 33       119
# 34     135.1
# 35     113.7
# 36     110.8
# 37     120.8
# 38     112.8
# 39     120.2
# 40     105.2
# 41     144.3
# 42     112.7
# 43     135.1
# 44     105.5
# 45     143.4
# 46       114
# 47     137.2
# 48     130.2
# 49     138.6
# 50     113.8
# 51     131.1
# 52     131.6
# 53     100.4
# 54     128.1
# 55       119
# 56     119.3
# 57     107.9
# 58     136.2
# 59      85.9
# 60      98.9
# 61       139
# 62     134.9
# 63       124
# 64     116.9
# 65       165
# ...

# %%
df_nm_drop['TSL \n(MM)'] = df_nm_drop['TSL \n(MM)'].astype(str).str.replace("cm", "", regex=False).astype(float)

# %%
X.loc[:, 'TSL \n(MM)'] = df_nm_drop['TSL \n(MM)']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_std_scaled = scaler.fit_transform(X)

# %%
X_std_scaled
# Out:
# array([[-1.85437633, -1.04558967, -0.68500077, ..., -0.97391091,
#         -0.36911635, -1.6549919 ],
#        [-1.85437633, -0.6728208 ,  0.07574254, ..., -0.17579102,
#         -0.62240476, -0.92440191],
#        [-1.85437633,  1.09377951,  0.04019379, ...,  0.46270489,
#          0.61412137, -0.37408738],
#        ...,
#        [ 1.87799358,  0.10513163,  1.46214391, ...,  1.31607923,
#         -0.88466797,  1.35181287],
#        [ 1.94125409,  1.88793928,  0.62319334, ...,  1.26696416,
#          0.68492246,  0.69807715],
#        [ 1.94125409, -0.34867396, -0.33662299, ..., -0.40908761,
#         -0.10485875, -0.69668555]])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_minMax_scaled = scaler.fit_transform(X)

# %%
X_minMax_scaled
# Out:
# array([[0.        , 0.3105802 , 0.46268657, ..., 0.34007585, 0.26061984,
#         0.17910448],
#        [0.        , 0.3890785 , 0.59577114, ..., 0.50442478, 0.23022616,
#         0.32276119],
#        [0.        , 0.76109215, 0.58955224, ..., 0.63590392, 0.37860476,
#         0.43097015],
#        ...,
#        [0.98333333, 0.55290102, 0.83830846, ..., 0.81163085, 0.19875553,
#         0.77033582],
#        [1.        , 0.92832765, 0.69154229, ..., 0.80151707, 0.38710063,
#         0.64179104],
#        [1.        , 0.45733788, 0.52363184, ..., 0.45638432, 0.29232978,
#         0.36753731]])

# %%
y
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 145    1
# 146    0
# 147    1
# 148    1
# 149    0
# Name: SEX, Length: 150, dtype: int64

# %%
# using StandardScaler normalized data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_std_scaled,y,test_size = 0.2)

# %%
# # using MinMaxScaler normalized data
# from sklearn.model_selection import train_test_split
# X_train,y_train,X_test,y_test = train_test_split(X_minMax_scaled,y,test_size = 0.2)

# %% [markdown]
# ## Training models using StandardScaler normalized data

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
lrc = LogisticRegression(solver='liblinear', penalty='l1')
knc = KNeighborsClassifier()
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
dtc = DecisionTreeClassifier(max_depth=5)
svc = SVC(kernel='sigmoid', gamma=1.0)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc,
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)

    return accuracy,precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.8333333333333334, 0.8)

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.8333333333333334
# Precision -  0.8
# For  KN
# Accuracy -  0.8666666666666667
# Precision -  0.8823529411764706
# For  DT
# Accuracy -  0.9
# Precision -  0.85
# For  LR
# Accuracy -  0.9
# Precision -  0.8888888888888888
# For  RF
# Accuracy -  0.9
# Precision -  0.8888888888888888
# For  AdaBoost
# Accuracy -  0.9
# Precision -  0.8888888888888888

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,
                               'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#   Algorithm  Accuracy  Precision
# 3        LR  0.900000   0.888889
# 4        RF  0.900000   0.888889
# 5  AdaBoost  0.900000   0.888889
# 1        KN  0.866667   0.882353
# 2        DT  0.900000   0.850000
# 0       SVC  0.833333   0.800000

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")
performance_df1
# Out:
#    Algorithm   variable     value
# 0         LR   Accuracy  0.900000
# 1         RF   Accuracy  0.900000
# 2   AdaBoost   Accuracy  0.900000
# 3         KN   Accuracy  0.866667
# 4         DT   Accuracy  0.900000
# 5        SVC   Accuracy  0.833333
# 6         LR  Precision  0.888889
# 7         RF  Precision  0.888889
# 8   AdaBoost  Precision  0.888889
# 9         KN  Precision  0.882353
# 10        DT  Precision  0.850000
# 11       SVC  Precision  0.800000
